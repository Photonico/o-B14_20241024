# %%
#!/usr/bin/env python3
from pathlib import Path

root = Path(".")   

limit_mb = 100
limit_bytes = limit_mb * 1024 * 1024

large_files = []

for path in root.rglob("*"):
    try:
        if path.is_file():
            size = path.stat().st_size
            if size > limit_bytes:
                large_files.append({
                    "size_MB": size / 1024 / 1024,
                    "path": str(path)
                })
    except PermissionError:
        print(f"Permission denied: {path}")
    except FileNotFoundError:
        pass

large_files = sorted(large_files, key=lambda x: x["size_MB"], reverse=True)

large_files
# Out:
# [{'size_MB': 2032.4320936203003,
#   'path': '.git\\objects\\pack\\pack-05c0dbe88c91f8c5c3df52b24edc8a84518bb283.pack'},
#  {'size_MB': 1886.9061994552612,
#   'path': '.git\\objects\\pack\\pack-7fb0f8649a3594e458092c3cfa15eb1ab657ffad.pack'},
#  {'size_MB': 904.1237497329712,
#   'path': '.git\\objects\\pack\\pack-6f9fe2969aca0c49570705ee51b7de3bde2f1f21.pack'},
#  {'size_MB': 749.749870300293,
#   'path': '.git\\objects\\pack\\pack-7bc69fa44624b42dda889834afc825692725b024.pack'},
#  {'size_MB': 416.9267578125,
#   'path': '3.1_bandstructure\\bilayer_HSE\\WAVECAR'}]
