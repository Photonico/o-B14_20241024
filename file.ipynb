# %%
#!/usr/bin/env python3
from pathlib import Path

root = Path(".")   

limit_mb = 100
limit_bytes = limit_mb * 1024 * 1024

large_files = []

for path in root.rglob("*"):
    try:
        if path.is_file():
            size = path.stat().st_size
            if size > limit_bytes:
                large_files.append({
                    "size_MB": size / 1024 / 1024,
                    "path": str(path)
                })
    except PermissionError:
        print(f"Permission denied: {path}")
    except FileNotFoundError:
        pass

large_files = sorted(large_files, key=lambda x: x["size_MB"], reverse=True)

large_files
# Out:
# [{'size_MB': 2797.6242599487305,
#   'path': '.git/objects/pack/pack-c4d606612f26ac75cab88b26e0387755d2a5e3ff.pack'},
#  {'size_MB': 2291.2968740463257, 'path': '.git/objects/pack/tmp_pack_NisSXt'},
#  {'size_MB': 2032.1574478149414,
#   'path': '.git/objects/pack/pack-343ca0d60bbd4c2c4923791b5fa1116c84e6479d.pack'},
#  {'size_MB': 496.7443780899048, 'path': '6.0_AIMD/bilayer_H/OUTCAR'},
#  {'size_MB': 364.4503173828125,
#   'path': '3.1_bandstructure/monolayer_FM_HSE06/WAVECAR'},
#  {'size_MB': 364.4503173828125,
#   'path': '3.1_bandstructure/monolayer_AFM_HSE06/WAVECAR'},
#  {'size_MB': 364.4503173828125,
#   'path': '3.1_bandstructure/monolayer_FM_HSE06/WAVECAR_OPT/WAVECAR'},
#  {'size_MB': 127.9839563369751,
#   'path': '3.1_bandstructure/monolayer_AFM_HSE06/CHGCAR'},
#  {'size_MB': 108.56057929992676, 'path': '6.0_AIMD/bilayer_H/vasprun.xml'}]
