# %% [markdown]
# # Convergence testing
#
# Energy versus parameters

# %%
# Prework

# from vmatplot.convergence import summarize_kpoints_lattice_energy, plot_kpoints_energy,specify_kpoints_energy

from vmatplot.convergence import *

import matplotlib.pyplot as plt

# %%
# K-points

summarize_energy_parameters("1.1_kpoints")

plot_energy_kpoints("for B₁₄","1.1_kpoints/parameters_energy.dat", (10,""))
