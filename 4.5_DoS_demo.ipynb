# %% [markdown]
# # Density of state
#
# Electronic density of state versus energy

# %%
# prework

from vmatplot.dos import plot_dos
import matplotlib.pyplot as plt

# %%
# Total DoS

systems = [["bulk o-B₁₄",                   "4.1_PDoS/o-B14_K20",               "unpolarized",  "blue"],
           ["monolayer o-B₁₄",              "4.1_PDoS/monolayer",               "unpolarized",  "green"],
           ["bilayer o-B₁₄",                "4.1_PDoS/bilayer",                 "unpolarized",  "yellow"],
           ["H-terminated bilayer o-B₁₄",   "4.1_PDoS/bilayer_with_Hydrogen",   "unpolarized",  "orange"]]

plot_dos("Total DoS", systems, 6, [0, 30], "Total")
