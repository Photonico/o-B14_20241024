# %% [markdown]
# # Density of state
#
# Electronic density of state versus energy

# %%
# prework

from vmatplot.dos import plot_dos
import matplotlib.pyplot as plt

# %%
# Total DoS

# systems = [
#     ["bulk o-B₁₄",   "4.1_PDoS/o-B14_K20",   "unpolarized",  "blue"]
#     # ["H-terminated bilyaer",              "5.0_PDoS/a-beryllene",         "unpolarized",          "blue"],
# ]

systems = ["bulk o-B₁₄","4.1_PDoS/o-B14_K20",   "unpolarized",  "blue"]

plot_dos("DoS", systems, 6, [0, 32], "Total")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       1 # Total DoS
#       2
#       3 # systems = [
#       4 #     ["bulk o-B₁₄",   "4.1_PDoS/o-B14_K20",   "unpolarized",  "blue"]
#       5 #     # ["H-terminated bilyaer",              "5.0_PDoS/a-beryllene",         "unpolarized",          "blue"],
#       6 # ]
#       8 systems = ["bulk o-B₁₄","4.1_PDoS/o-B14_K20",   "unpolarized",  "blue"]
# ---> 10 plot_dos("DoS", systems, 6, [0, 32], "Total")
#
# File ~/Repos/o-B14_20241024/vmatplot/dos.py:639, in plot_dos(title, matters_list, x_range, y_lim, dos_quantity)
#     637 fermi_energy_text = f"Fermi energy\n{efermi:.3f} (eV)"
#     638 if len(matters) == 1:
# --> 639     plt.text(efermi-shift-x_range*0.02, y_lim*0.98, fermi_energy_text, fontsize =1.0*12, c=fermi_color[0], rotation=0, va = "top", ha="right")
#     640 else: pass
#     641 # Title
#     642 # plt.title(f"Electronic density of state for {title} ({supplement})")
#
# TypeError: can't multiply sequence by non-int of type 'float'
