# %% [markdown]
# # Density of state
#
# Electronic density of state versus energy

# %%
# prework

from vmatplot.dos import plot_dos
import matplotlib.pyplot as plt

# %%
# Total DoS

systems = [["bulk",                 "4.1_PDoS/o-B14_K20",               "unpolarized",  "blue"],
           ["monolayer",            "4.1_PDoS/monolayer",               "unpolarized",  "green"],
           ["bilayer",              "4.1_PDoS/bilayer",                 "unpolarized",  "yellow"],
           ["H-terminated bilayer", "4.1_PDoS/bilayer_with_Hydrogen",   "unpolarized",  "orange"]]

plot_dos("Total DoS for o-B₁₄ systems", systems, 6, [0, 27], "Total")

plt.savefig("figures/4.0_total_dos.pdf")
plt.savefig("figures_collection/S2.12.pdf")
