# %% [markdown]
# # Phonon dispersion

# %%
# testing area

bs = "3.1_bandstructure/o-B14_K12"
pd = "3.0_phonon_dispersion/bilayer_with_Hydrogen"

from vmatplot.phonon import *
from vmatplot.bandstructure import *

# %%
is_qpoints_returning(pd)
# Out:
# True

# %%
is_kpoints_returning(bs)
# Out:
# False
