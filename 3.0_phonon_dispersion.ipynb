# %% [markdown]
# # Phonon dispersion

# %%
# testing area

from vmatplot.phonon import plot_phonons
import matplotlib.pyplot as plt

# %%
# # Phonon dispersion 3×3

# matters = [["monolayer 3×3", "3.0_phonon_dispersion/monolayer_3",                   "cyan",     "solid",    1.5, 1.0, 0],
#            ["monolayer with Hydrogen 3×3", "3.0_phonon_dispersion/monolayer_H_3",   "lime",     "solid",    1.5, 1.0, 0],
#            ["bilayer 3×3", "3.0_phonon_dispersion/bilayer_3",                       "yellow",   "solid",    1.5, 1.0, 0],
#            ["bilayer with Hydrogen 3×3", "3.0_phonon_dispersion/bilayer_H_3",       "orange",   "solid",    1.5, 1.0, 0]
#            ]

# plot_phonons("Phonon dispersion", matters, [-1,7], "upper right")
# plt.savefig("figures/3.12_phonon_3.pdf")

# %%
# Phonon dispersion 3×3

matters = [["monolayer 3×3", "3.0_phonon_dispersion_vasp/monolayer_3",                   "cyan",     "solid",    1.5, 1.0, 0],
           ["monolayer with Hydrogen 3×3", "3.0_phonon_dispersion_phononpy/monolayer_top",   "lime",     "solid",    1.5, 1.0, 0],
           ["bilayer 3×3", "3.0_phonon_dispersion_vasp/bilayer_3",                       "yellow",   "solid",    1.5, 1.0, 0],
           ]

plot_phonons("Phonon dispersion", matters, [-1,7], "upper right")
plt.savefig("figures/3.13_phonon_noHydrogen_3.pdf")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 8
#       1 # Phonon dispersion 3×3
#       3 matters = [["monolayer 3×3", "3.0_phonon_dispersion_vasp/monolayer_3",                   "cyan",     "solid",    1.5, 1.0, 0],
#       4            ["monolayer with Hydrogen 3×3", "3.0_phonon_dispersion_phononpy/monolayer_top",   "lime",     "solid",    1.5, 1.0, 0],
#       5            ["bilayer 3×3", "3.0_phonon_dispersion_vasp/bilayer_3",                       "yellow",   "solid",    1.5, 1.0, 0],
#       6            ]
# ----> 8 plot_phonons("Phonon dispersion", matters, [-1,7], "upper right")
#       9 plt.savefig("figures/3.13_phonon_noHydrogen_3.pdf")
#
# File /cmt2/lniu6305/o-B14_20241024/vmatplot/phonon.py:351, in plot_phonons(title, matters_list, eigen_range, legend_loc)
#     348 annotate_color = color_sampling("Grey")
#     350 # Create matters using the updated create_matters_phonons
# --> 351 matters = create_matters_phonons(matters_list)
#     352 # Use the weighted q-path from one of the matters (they should be identical)
#     353 weighted_qpath = matters[0][2]
#
# File /cmt2/lniu6305/o-B14_20241024/vmatplot/phonon.py:304, in create_matters_phonons(matters_list)
#     301 backend = detect_phonon_backend(directory)
#     303 if backend == "phonopy":
# --> 304     bands_data = extract_phonopy_bands(directory)
#     305     qpath = bands_data["path"]
#     306     bands = bands_data["bands"]
#
# File /cmt2/lniu6305/o-B14_20241024/vmatplot/phonon.py:469, in extract_phonopy_bands(directory, band_yaml)
#     467 band_path = os.path.join(directory, band_yaml)
#     468 if not os.path.isfile(band_path):
# --> 469     raise FileNotFoundError(f"{band_yaml} not found under '{directory}'. (Try: phonopy -p band.conf)")
#     470 try:
#     471     import yaml  # type: ignore
#
# FileNotFoundError: band.yaml not found under '3.0_phonon_dispersion_phononpy/monolayer_top'. (Try: phonopy -p band.conf)
