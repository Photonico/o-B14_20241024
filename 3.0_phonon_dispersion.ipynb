# %% [markdown]
# # Phonon dispersion

# %%
# testing area

from vmatplot.phonon import plot_phonons
import matplotlib.pyplot as plt

# %%
# Phonon dispersion

matters = [["monolayer", "3.0_phonon_dispersion/monolayer", "yellow", "solid", 1.5, 1.0, 0],
           ["monolayer with Hydrogen", "3.0_phonon_dispersion/monolayer_with_Hydrogen", "orange", "solid", 1.5, 1.0, 0],
           ["bilayer", "3.0_phonon_dispersion/bilayer", "blue", "solid", 1.5, 1.0, 0],
           ["bilayer with Hydrogen", "3.0_phonon_dispersion/bilayer_with_Hydrogen", "violet", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion", matters, [-4,4], "upper right")
plt.savefig("figures/3.11_phonon_monolayer.pdf")
