# %% [markdown]
# # Phonon dispersion

# %%
# testing area

from vmatplot.phonon import plot_phonons
import matplotlib.pyplot as plt

# %%
# Phonon dispersion 2×2

dendotted = (0,(1,1))

matters = [["monolayer 2×2", "3.0_phonon_dispersion/monolayer_2",                   "cyan",    "solid",  1.5, 1.0, 0],
           ["monolayer with Hydrogen 2×2", "3.0_phonon_dispersion/monolayer_H_2",   "lime",    "solid",  1.5, 1.0, 0],
           ["bilayer 2×2", "3.0_phonon_dispersion/bilayer_2",                       "yellow",  "solid",  1.5, 1.0, 0],
           ["bilayer with Hydrogen 2×2", "3.0_phonon_dispersion/bilayer_H_2",       "orange",  "solid",  1.5, 1.0, 0]]

plot_phonons("Phonon dispersion", matters, [-2,6], "upper right")
plt.savefig("figures/3.11_phonon_2.pdf")

# %%
# Phonon dispersion 3×3

matters = [["monolayer 3×3", "3.0_phonon_dispersion/monolayer_3",                   "cyan",     "solid",    1.5, 1.0, 0],
         #   ["monolayer with Hydrogen 3×3", "3.0_phonon_dispersion/monolayer_H_3",   "lime",     "solid",    1.5, 1.0, 0],
           ["bilayer 3×3", "3.0_phonon_dispersion/bilayer_3",                       "yellow",   "solid",    1.5, 1.0, 0],
        #    ["bilayer with Hydrogen 3×3", "3.0_phonon_dispersion/bilayer_H_3",       "orange",   "solid",    1.5, 1.0, 0]
           ]

plot_phonons("Phonon dispersion", matters, [-2,6], "upper right")
plt.savefig("figures/3.12_phonon_3.pdf")

# %%
# Phonon dispersion 3×3

matters = [["monolayer 3×3", "3.0_phonon_dispersion/monolayer_3",                   "cyan",     "solid",    1.5, 1.0, 0],
           ["bilayer 3×3", "3.0_phonon_dispersion/bilayer_3",                       "yellow",   "solid",    1.5, 1.0, 0],
           ]

plot_phonons("Phonon dispersion", matters, [-2,6], "upper right")
plt.savefig("figures/3.13_phonon_noHydrogen_3.pdf")
