# %% [markdown]
# # Projected electronic density for specify components
#
# Compoemts analysis for projected electronic density of state versus energy

# %%
# prework

from vmatplot.pdos import plot_single_pdos
import matplotlib.pyplot as plt

# %%
# o-B14 Bulk

B2_index = (5,8)
B3_index = [1,2,3,4,13,14]
B7_index = (1,14)
current_dict = "4.1_PDoS/o-B14_K20"

systems = [["Total PDoS", current_dict, [], "total", "grey", "solid", 2.0, 1.0],
           ["$p$ for B₂ structure", current_dict, B2_index, "p", "blue", "solid", 2.0, 1.0],
           ["$s$ for B₂ structure", current_dict, B2_index, "s", "blue", "dashed", 2.0, 1.0],
           ["$p$ for B₃ structure", current_dict, B3_index, "p", "Lime", "solid", 2.0, 1.0],
           ["$s$ for B₃ structure", current_dict, B3_index, "s", "Lime", "dashed", 2.0, 1.0],
           ["$p$ for B₇ structure", current_dict, B7_index, "p", "Orange", "solid", 2.0, 1.0],
           ["$s$ for B₇ structure", current_dict, B7_index, "s", "Orange", "dashed", 2.0, 1.0]]

plot_single_pdos("PDoS for o-B₁₄ Bulk", systems, 6, 8)
plt.savefig("figures/4.20_PDoS_bulk.pdf")
