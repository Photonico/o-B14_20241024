# %% [markdown]
# # Projected electronic density for specify components
#
# Compoemts analysis for projected electronic density of state versus energy

# %%
# prework

from vmatplot.pdos import plot_single_pdos
import matplotlib.pyplot as plt

# %%
# o-B14 Bulk

B2_index = (5,8)
B3_index = [1,2,3,4,13,14]
B7_index = (1,14)
current_dict = "4.1_PDoS/o-B14_K20"

systems = [["Total PDoS", current_dict, [], "total", "grey", "solid", 2.0, 1.0],
           ["$p$ for Group 1", current_dict, B2_index, "p", "blue", "solid", 2.0, 1.0],
           ["$s$ for Group 1", current_dict, B2_index, "s", "blue", "dashed", 2.0, 1.0],
           ["$p$ for Group 2", current_dict, B3_index, "p", "Orange", "solid", 2.0, 1.0],
           ["$s$ for Group 3", current_dict, B3_index, "s", "Orange", "dashed", 2.0, 1.0],
           ["$p$ for Group 3", current_dict, B7_index, "p", "Purple", "solid", 2.0, 1.0],
           ["$s$ for Group 3", current_dict, B7_index, "s", "Purple", "dashed", 2.0, 1.0]]

plot_single_pdos("PDoS for o-B₁₄ Bulk", systems, 6, 8)
plt.savefig("figures_collection/proj3.2b.pdf")
# Out:
# Error in extract_dict_pdos: module 'numpy' has no attribute 'trapz'
# Warning: Skipping Total PDoS because PDoS data could not be extracted.
# Error in extract_dict_pdos: module 'numpy' has no attribute 'trapz'
# Warning: Skipping $p$ for Group 1 because PDoS data could not be extracted.
# Error in extract_dict_pdos: module 'numpy' has no attribute 'trapz'
# Warning: Skipping $s$ for Group 1 because PDoS data could not be extracted.
# Error in extract_dict_pdos: module 'numpy' has no attribute 'trapz'
# Warning: Skipping $p$ for Group 2 because PDoS data could not be extracted.
# Error in extract_dict_pdos: module 'numpy' has no attribute 'trapz'
# Warning: Skipping $s$ for Group 3 because PDoS data could not be extracted.
# Error in extract_dict_pdos: module 'numpy' has no attribute 'trapz'
# Warning: Skipping $p$ for Group 3 because PDoS data could not be extracted.
# Error in extract_dict_pdos: module 'numpy' has no attribute 'trapz'
# Warning: Skipping $s$ for Group 3 because PDoS data could not be extracted.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 16
#       6 current_dict = "4.1_PDoS/o-B14_K20"
#       8 systems = [["Total PDoS", current_dict, [], "total", "grey", "solid", 2.0, 1.0],
#       9            ["$p$ for Group 1", current_dict, B2_index, "p", "blue", "solid", 2.0, 1.0],
#      10            ["$s$ for Group 1", current_dict, B2_index, "s", "blue", "dashed", 2.0, 1.0],
#    (...)     13            ["$p$ for Group 3", current_dict, B7_index, "p", "Purple", "solid", 2.0, 1.0],
#      14            ["$s$ for Group 3", current_dict, B7_index, "s", "Purple", "dashed", 2.0, 1.0]]
# ---> 16 plot_single_pdos("PDoS for o-B₁₄ Bulk", systems, 6, 8)
#      17 plt.savefig("figures_collection/proj3.2b.pdf")
#
# File ~/Repos/o-B14_20241024/vmatplot/pdos.py:2416, in plot_single_pdos(title, matters_list, x_range, y_top)
#    2414 plt.axvline(x=0, linestyle="--", color=fermi_color[0], alpha=0.8, label="Fermi energy")
#    2415 if matters_list:  # Use the first valid pdos_data for Fermi energy annotation
# -> 2416     fermi_energy_text = f"Fermi energy\n({pdos_data['efermi']:.3f} eV)"
#    2417     plt.text(-x_range * 0.02, y_top * 0.98, fermi_energy_text,
#    2418              fontsize=12, color=fermi_color[0], rotation=0, va="top", ha="right")
#    2420 # Plot settings
#
# TypeError: 'NoneType' object is not subscriptable
