# %% [markdown]
# # Linear Optical Properties

# %%
# prework

from vmatplot.linear_optical_properties import plot_linear_optical_property
import matplotlib.pyplot as plt

components = [{"xx":"in-plane"}, {"zz":"out-of-plane"}, {"xy":"xy-component"}]
boundary = (0,12)
layout = "hor"

systems = [["o-B₁₄ bilayer with Hydrogen",  "5.1_dielectric_function/bilayer_with_Hydrogen", "orange"],
           ["o-B₁₄ bilayer",    "5.1_dielectric_function/bilayer",          "yellow"],
           ["o-B₁₄ monolayer",  "5.1_dielectric_function/monolayer",        "green"],
           ["o-B₁₄",            "5.1_dielectric_function/o-B14_n128_k34",   "blue"]]

# %%
# Absorption coefficient by GGA-PBE

plot_linear_optical_property("Absorption coefficient for o-B₁₄", systems, "absorption", components, layout, True, "eV", boundary, True)
plt.savefig("figures/6.1_absorption.pdf")

# %%
# Refractive index by GGA-PBE

plot_linear_optical_property("Refractive index for o-B₁₄", systems, "refractive", components, layout, True, "eV", boundary, True)
plt.savefig("figures/6.2_refractive.pdf")

# %%
# Extinction coefficient by GGA-PBE

plot_linear_optical_property("Extinction coefficient for o-B₁₄", systems, "extinction", components, layout, True, "eV", boundary, True)
plt.savefig("figures/6.3_extinction.pdf")

# %%
# Reflectivity by GGA-PBE

plot_linear_optical_property("Reflectivity for o-B₁₄", systems, "reflectivity", components, layout, True, "eV", boundary, True)
plt.savefig("figures/6.4_reflectivity.pdf")

# %%
# Energy-loss spectrum by GGA-PBE

plot_linear_optical_property("Energy-loss spectrum for o-B₁₄", systems, "energy-loss", components, layout, True, "eV", boundary, True)
plt.savefig("figures/6.5_energy-loss.pdf")
# Out:
# /cmt2/lniu6305/o-B14_20241024/vmatplot/linear_optical_properties.py:49: RuntimeWarning: invalid value encountered in true_divide
#   spectrum = (density_energy_imag)/(np.square(density_energy_real)+np.square(density_energy_imag))
# /cmt2/lniu6305/o-B14_20241024/vmatplot/linear_optical_properties.py:49: RuntimeWarning: invalid value encountered in true_divide
#   spectrum = (density_energy_imag)/(np.square(density_energy_real)+np.square(density_energy_imag))
# /cmt2/lniu6305/o-B14_20241024/vmatplot/linear_optical_properties.py:49: RuntimeWarning: invalid value encountered in true_divide
#   spectrum = (density_energy_imag)/(np.square(density_energy_real)+np.square(density_energy_imag))
