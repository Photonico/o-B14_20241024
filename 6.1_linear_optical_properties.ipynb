# %% [markdown]
# # Linear Optical Properties

# %%
# prework

from vmatplot.linear_optical_properties import plot_merged_linear_optical_property

import matplotlib.pyplot as plt

components = [{"xx":"in-plane"},{"zz":"out-of-plane"}]
boundary = (1.24, 32)
layout = "hor"

systems = ["", "5.1_dielectric_function/o-B14_n128_k34", "blue", "solid", 2.0]

# %%
# Absorption coefficient by GGA-PBE

plot_merged_linear_optical_property("Absorption coefficient for o-B₁₄", systems, "absorption", components, layout, "eV", boundary)
plt.savefig("figures/6.1_absorption.pdf")

# %%
# Refractive index by GGA-PBE

plot_merged_linear_optical_property("Refractive index for o-B₁₄", systems, "refractive", components, layout, "eV", boundary)
plt.savefig("figures/6.2_refractive.pdf")

# %%
# Extinction coefficient by GGA-PBE

plot_merged_linear_optical_property("Extinction coefficient for o-B₁₄", systems, "extinction", components, layout, "eV", boundary)
plt.savefig("figures/6.3_extinction.pdf")

# %%
# Reflectivity by GGA-PBE

plot_merged_linear_optical_property("Reflectivity for o-B₁₄", systems, "reflectivity", components, layout, "eV", boundary)
plt.savefig("figures/6.4_reflectivity.pdf")

# %%
# Energy-loss spectrum by GGA-PBE

plot_merged_linear_optical_property("Energy-loss spectrum for o-B₁₄", systems, "energy-loss", components, layout, "eV", boundary)
plt.savefig("figures/6.5_energy-loss.pdf")
