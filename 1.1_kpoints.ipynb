# %% [markdown]
# # Kpoints
#
# Free energy versus K-points

# %%
# Prework

from vmatplot.kpoints import summarize_kpoints_free_energy, plot_kpoints_free_energy_data

import matplotlib.pyplot as plt

# %%
# B₁₄

# summarize_kpoints_free_energy("1_Kpoints")

plot_kpoints_free_energy_data("for B₁₄","1_kpoints/energy_kpoints.dat", (10,""))
