# %% [markdown]
# # Bandstructure with DoS

# %%
# Prework

from vmatplot.bandstructure import plot_bsDoS
import matplotlib.pyplot as plt

# %%
# o-B14

bsDoS_list = ["monocolor", "", "3.1_bandstructure/o-B14_K48", "4.1_PDoS/o-B14_K20"]

plot_bsDoS("Band structure and DoS for bulk o-B₁₄", bsDoS_list, 4, 16, False)
plt.savefig("figures/3.31_bsDoS_o-B14.pdf")

# %%
# o-B14 monolayer

bsDoS_list = [["monocolor", "", "3.1_bandstructure/monolayer", "4.1_PDoS/monolayer"]]

plot_bsDoS("Band structure and DoS for monolayer o-B₁₄", bsDoS_list, 4, 16, False)
plt.savefig("figures/3.32_bsDoS_monolayer.pdf")

# %%
# o-B14 bilayer

bsDoS_list = [["monocolor", "", "3.1_bandstructure/bilayer", "4.1_PDoS/bilayer", "blue"]]

plot_bsDoS("Band structure and DoS for bilayer o-B₁₄", bsDoS_list, 4, 16, False)
plt.savefig("figures/3.33_bsDoS_bilayer.pdf")

# %%
# o-B14 bilayer

bsDoS_list = [["monocolor", "", "3.1_bandstructure/bilayer_with_Hydrogen", "4.1_PDoS/bilayer_with_Hydrogen"]]

plot_bsDoS("Band structure and DoS for bilayer o-B₁₄ with hydrogen termination", bsDoS_list, 4, 20, False)
plt.savefig("figures/3.34_bsDoS_bilayer_with_Hydrogen.pdf")
plt.savefig("figures_collection/fig2.8.pdf")
