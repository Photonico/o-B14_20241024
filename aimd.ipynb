# %% [markdown]
# # Ab initio Molecular Dynamics

# %%
from vmatplot.aimd import plot_aimd

fig, axes, aimd_data = plot_aimd(
    "AIMD simulation of o-B14 bulk",
    "6.0_AIMD/bilayer_H",
    energy_key="F",
    time_step=1.0,
    x_boundary=(0, 5500),
    temperature_boundary=(0, 800),
)

# plt.savefig("figures/aimd_bulk.pdf", bbox_inches="tight")
