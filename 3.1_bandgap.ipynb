# %% [markdown]
# # Bandgap and bandstructure testing

# %%
# Prework

from vmatplot.bandstructure import *

# %%
# o-B14

print("For o-B₁₄")
# If number of points along each segment of the high-symmetry path is 48
current_density = extract_bandgap_OUTCAR("3.1_bandstructure/o-B14_K48")
current_output = (
    f"\tthe bandgap is {current_density['bandgap']}; \n"
    f"\tHOMO band index is {current_density['HOMO index']} and HOMO energy is {current_density['HOMO']}; \n"
    f"\tLUMO band index is {current_density['LUMO index']} and LUMO energy is {current_density['LUMO']}"
)
print(current_output)
# Out:
# For o-B₁₄
# 	the bandgap is -217.9512;
# 	HOMO band index is 21 and HOMO energy is 219.0;
# 	LUMO band index is 22 and LUMO energy is 1.0488

# %%
# o-B14 monolayer

print("For o-B₁₄ monolayer")
# If number of points along each segment of the high-symmetry path is 48
current_density = extract_bandgap_OUTCAR("3.1_bandstructure/monolayer")
current_output = (
    f"\tthe bandgap is {current_density['bandgap']}; \n"
    f"\tHOMO band index is {current_density['HOMO index']} and HOMO energy is {current_density['HOMO']}; \n"
    f"\tLUMO band index is {current_density['LUMO index']} and LUMO energy is {current_density['LUMO']}"
)
print(current_output)
# Out:
# For o-B₁₄ monolayer
# 	the bandgap is -25.380200000000002;
# 	HOMO band index is 21 and HOMO energy is 21.0;
# 	LUMO band index is 22 and LUMO energy is -4.3802

# %%
# o-B14 bilayer

print("For o-B₁₄ bilayer")
# If number of points along each segment of the high-symmetry path is 48
current_density = extract_bandgap_OUTCAR("3.1_bandstructure/bilayer")
current_output = (
    f"\tthe bandgap is {current_density['bandgap']}; \n"
    f"\tHOMO band index is {current_density['HOMO index']} and HOMO energy is {current_density['HOMO']}; \n"
    f"\tLUMO band index is {current_density['LUMO index']} and LUMO energy is {current_density['LUMO']}"
)
print(current_output)
# Out:
# For o-B₁₄ bilayer
# 	the bandgap is -43.3703;
# 	HOMO band index is 42 and HOMO energy is 42.0;
# 	LUMO band index is 43 and LUMO energy is -1.3703

# %%
# o-B14 bilayer with Hydrogen

print("For o-B₁₄ bilayer")
# If number of points along each segment of the high-symmetry path is 48
current_density = extract_bandgap_OUTCAR("3.1_bandstructure/bilayer_with_Hydrogen")
current_output = (
    f"\tthe bandgap is {current_density['bandgap']}; \n"
    f"\tHOMO band index is {current_density['HOMO index']} and HOMO energy is {current_density['HOMO']}; \n"
    f"\tLUMO band index is {current_density['LUMO index']} and LUMO energy is {current_density['LUMO']}"
)
print(current_output)
# Out:
# For o-B₁₄ bilayer
# 	the bandgap is -48.6718;
# 	HOMO band index is 44 and HOMO energy is 44.0;
# 	LUMO band index is 45 and LUMO energy is -4.6718
