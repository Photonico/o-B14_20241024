# %% [markdown]
# # Dielectric function

# %%
# Prework

from vmatplot.dielectric_function import *
import matplotlib.pyplot as plt

# %%
# # Dielectric function

dielectric_list = [["o-B₁₄ bilayer with Hydrogen",  "5.1_dielectric_function/bilayer_with_Hydrogen", "orange"],
                   ["o-B₁₄ bilayer",    "5.1_dielectric_function/bilayer",          "yellow"],
                   ["o-B₁₄ monolayer",  "5.1_dielectric_function/monolayer",        "green"],
                   ["o-B₁₄",            "5.1_dielectric_function/o-B14_n128_k34",   "blue"]]
components = [{"xx":"in-plane"},{"zz":"out-of-plane"}, {"xy":"xy-component"}]

plot_dielectric_function("Dielectric function", dielectric_list, components, "hor", True, "eV", (0,12), True)
plt.savefig("figures/5.10_dielectric_o-B14.pdf")

# %%
# Dielectric function for nbands

dielectric_list = [["(32 nbands)", "5.1_dielectric_function/o-B14_n32_k10", "red",      "solid", 3.2, 1.0],
                   ["(64 nbands)", "5.1_dielectric_function/o-B14_n64_k10", "orange",   "solid", 2.8, 1.0],
                   ["(128 nbands)", "5.1_dielectric_function/o-B14_n128_k10", "green",  "solid", 2.4, 1.0],
                   ["(256 nbands)", "5.1_dielectric_function/o-B14_n256_k10", "blue",   "solid", 2.0, 1.0]]

plot_dielectric_function("Dielectric function versus NBANDS for o-B₁₄", dielectric_list, components, "hor", True, "eV", (1.24, 32))
plt.savefig("figures/5.11_dielectric_o-B14.pdf")

# %%
# Dielectric function for k-points

dielectric_list = [["(10  14  9)", "5.1_dielectric_function/o-B14_n128_k10",  "green"   ],
                   ["(20  28  18)", "5.1_dielectric_function/o-B14_n128_k20", "red"     ],
                   ["(26  37  24)", "5.1_dielectric_function/o-B14_n128_k26", "orange"  ],
                   ["(30  42  28)", "5.1_dielectric_function/o-B14_n128_k30", "yellow"  ],
                   ["(32  45  29)", "5.1_dielectric_function/o-B14_n128_k32", "green"   ],
                   ["(34  48  31)", "5.1_dielectric_function/o-B14_n128_k34", "blue"    ]]

plot_dielectric_function("Dielectric function versus k-points for o-B₁₄", dielectric_list, components, "hor", True, "eV", (1.24, 32))
plt.savefig("figures/5.12_dielectric_o-B14.pdf")
