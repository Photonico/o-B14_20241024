# %% [markdown]
# # Convergence testing for o-B14 monolayer
#
# Energy versus parameters

# %%
# Prework

# from vmatplot.convergence import summarize_parameters, summarize_cohesive_energy, plot_energy_parameters
from vmatplot.convergence import *
from vmatplot.commons import identify_parameters

import matplotlib.pyplot as plt

vaccum_boundary = (0, 40)

# %%
# 1.9 energy versus vaccuum

summarize_parameters("1.2_convergence_monolayer/energy_vacuum")
vaccum_list = ["", "1.2_convergence_monolayer/energy_vacuum/energy_parameters.dat", vaccum_boundary, "blue"]

plot_energy_parameters("Energy versus vacuum for o-B₁₄ monolayer", "a3", vaccum_list)
plt.savefig("figures/1.9_energy_vaccum_monolayer.pdf")

# %%
# 1.10 free boron energy

para_b = identify_parameters("1.0_cohesive_energy")

for key, value in para_b.items():
    print(f"{key}: {value}")
# Out:
# total atom count: 1
# total energy: -0.3103598
# fermi energy: -4.00048076
# total kpoints: 1
# calculated kpoints: 1
# kpoints mesh: (1, 1, 1)
# lattice constant: 15.0
# symmetry precision (SYMPREC): 1e-05
# energy cutoff (ENCUT): 600.0
# k-point spacing (KSPACING): None
# volume: None
# time step (POTIM): 0.5
# mixing parameter (AMIX): None
# mixing parameter (BMIX): None
# electronic convergence (EDIFF): 1e-06
# force convergence (EDIFFG): -0.001
# elapsed time (sec): 39.575
# Scaling: 1.0
# a1: 15.0
# a2: 12.5
# a3: 18.0

# %%
# 1.1a lattice parameters for borophene

para_borophene = identify_parameters("1.6_convergence_borophene/parameters")

for key, value in para_borophene.items():
    print(f"{key}: {value}")
# Out:
# total atom count: 8
# total energy: -50.47945317
# fermi energy: -2.23596029
# total kpoints: 289
# calculated kpoints: 33
# kpoints mesh: (17, 17, 1)
# lattice constant: 5.05099972762185
# symmetry precision (SYMPREC): 1e-05
# energy cutoff (ENCUT): 600.0
# k-point spacing (KSPACING): None
# volume: None
# time step (POTIM): 0.5
# mixing parameter (AMIX): None
# mixing parameter (BMIX): None
# electronic convergence (EDIFF): 1e-06
# force convergence (EDIFFG): -0.001
# elapsed time (sec): 142.131
# Scaling: 1.0
# a1: 5.05099972762185
# a2: 5.05099972762185
# a3: 15.0

# %%
# 1.1b cohesive energy for borophene

coh_borophene = summarize_cohesive_energy("1.6_convergence_borophene/parameters","1.0_cohesive_energy")

for key, value in coh_borophene.items():
    print(f"{key}: {value}")
# Out:
# total atom count: 8
# total energy: -50.47945317
# atom energy: -0.3103598
# cohesive energy: -5.99957184625
# total kpoints: 289
# kpoints mesh: (17, 17, 1)
# energy cutoff (ENCUT): 600.0
# Scaling: 1.0
# lattice constant: 5.05099972762185

# %%
# 1.2a lattice parameters for monolayer

para_monolayer = identify_parameters("1.2_convergence_monolayer/parameters")

for key, value in para_monolayer.items():
    print(f"{key}: {value}")
# Out:
# total atom count: 14
# total energy: -85.29945521
# fermi energy: -4.35374252
# total kpoints: 90
# calculated kpoints: 25
# kpoints mesh: (10, 9, 1)
# lattice constant: 5.69975798
# symmetry precision (SYMPREC): 1e-05
# energy cutoff (ENCUT): 600.0
# k-point spacing (KSPACING): None
# volume: None
# time step (POTIM): 0.5
# mixing parameter (AMIX): None
# mixing parameter (BMIX): None
# electronic convergence (EDIFF): 1e-06
# force convergence (EDIFFG): -0.01
# elapsed time (sec): 185.631
# Scaling: 1.0
# a1: 5.699757976020235
# a2: 6.314133778398662
# a3: 24.044058323

# %%
# 1.2b cohesive energy for monolayer

coh_monolayer = summarize_cohesive_energy("1.2_convergence_monolayer/parameters","1.0_cohesive_energy")

for key, value in coh_monolayer.items():
    print(f"{key}: {value}")
# Out:
# total atom count: 14
# total energy: -85.29945521
# atom energy: -0.3103598
# cohesive energy: -5.7824584292857155
# total kpoints: 90
# kpoints mesh: (10, 9, 1)
# energy cutoff (ENCUT): 600.0
# Scaling: 1.0
# lattice constant: 5.69975798

# %%
# 1.3a lattice parameters for bilayer

para_bilayer = identify_parameters("1.3_convergence_bilayer/parameters")

for key, value in para_bilayer.items():
    print(f"{key}: {value}")
# Out:
# total atom count: 28
# total energy: -177.73499848
# fermi energy: -1.46861616
# total kpoints: 90
# calculated kpoints: 25
# kpoints mesh: (10, 9, 1)
# lattice constant: 5.71949249
# symmetry precision (SYMPREC): 1e-05
# energy cutoff (ENCUT): 600.0
# k-point spacing (KSPACING): None
# volume: None
# time step (POTIM): 0.5
# mixing parameter (AMIX): None
# mixing parameter (BMIX): None
# electronic convergence (EDIFF): 1e-06
# force convergence (EDIFFG): -0.01
# elapsed time (sec): 912.709
# Scaling: 1.0
# a1: 5.719492487400801
# a2: 6.349095585693292
# a3: 28.088116646

# %%
# 1.3b cohesive energy for bilayer

coh_bilayer = summarize_cohesive_energy("1.3_convergence_bilayer/parameters","1.0_cohesive_energy")

for key, value in coh_bilayer.items():
    print(f"{key}: {value}")
# Out:
# total atom count: 28
# total energy: -177.73499848
# atom energy: -0.3103598
# cohesive energy: -6.037318717142857
# total kpoints: 90
# kpoints mesh: (10, 9, 1)
# energy cutoff (ENCUT): 600.0
# Scaling: 1.0
# lattice constant: 5.71949249

# %%
# 1.4a lattice parameters for monolayer with Hydrogen

para_monolayer_hydrogen = identify_parameters("1.4_convergence_monolayer_with_Hydrogen/parameters")

for key, value in para_monolayer_hydrogen.items():
    print(f"{key}: {value}")
# Out:
# total atom count: 18
# total energy: -103.07696875
# fermi energy: -5.31335022
# total kpoints: 90
# calculated kpoints: 25
# kpoints mesh: (10, 9, 1)
# lattice constant: 5.69417549
# symmetry precision (SYMPREC): 1e-05
# energy cutoff (ENCUT): 600.0
# k-point spacing (KSPACING): None
# volume: None
# time step (POTIM): 0.5
# mixing parameter (AMIX): None
# mixing parameter (BMIX): None
# electronic convergence (EDIFF): 1e-06
# force convergence (EDIFFG): -0.01
# elapsed time (sec): 453.319
# Scaling: 1.0
# a1: 5.694175492057987
# a2: 6.13376935405964
# a3: 26.0440578461

# %%
# 1.5a lattice parameters for bilayer with Hydrogen

para_bilayer_hydrogen = identify_parameters("1.5_convergence_bilayer_with_Hydrogen/parameters")

for key, value in para_bilayer_hydrogen.items():
    print(f"{key}: {value}")
# Out:
# total atom count: 32
# total energy: -197.37989028
# fermi energy: -4.14802011
# total kpoints: 90
# calculated kpoints: 25
# kpoints mesh: (10, 9, 1)
# lattice constant: 5.67999605
# symmetry precision (SYMPREC): 1e-05
# energy cutoff (ENCUT): 600.0
# k-point spacing (KSPACING): None
# volume: None
# time step (POTIM): 0.5
# mixing parameter (AMIX): None
# mixing parameter (BMIX): None
# electronic convergence (EDIFF): 1e-06
# force convergence (EDIFFG): -0.01
# elapsed time (sec): 1024.381
# Scaling: 1.0
# a1: 5.679996051201121
# a2: 6.147111186319336
# a3: 30.088116646
