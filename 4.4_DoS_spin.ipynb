# %% [markdown]
# # DoS with spin

# %%
# prework

from vmatplot.dos import plot_dos_spin
import matplotlib.pyplot as plt

# %%
# FM

matter = [["FM", "4.1_PDoS/monolayer_FM_ollie", "spin-up", "Cyan"],
          ["FM", "4.1_PDoS/monolayer_FM_ollie", "spin-down", "Orange"],
          ["FM", "4.1_PDoS/monolayer_FM_ollie", "total", "Blue"]]

plot_dos_spin( "FM DoS for o-B₁₄ monolayer", matter, [-8, 4], [-6, 10], "Total")

# %%
# AFM

matter = ["Total", "4.1_PDoS/monolayer_AFM_ollie", "spin up", "Purple"]

plot_dos_spin( "AFM DoS for o-B₁₄ monolayer", matter, [-8, 4], [-8, 8], "Total")
