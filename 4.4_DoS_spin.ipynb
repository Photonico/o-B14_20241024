# %% [markdown]
# # DoS with spin

# %%
# prework

from vmatplot.dos import plot_dos_spin
import matplotlib.pyplot as plt

# %%
# FM

plot_dos_spin( "FM DoS for o-B₁₄ monolayer", [
    ["Total", "4.1_PDoS/monolayer_FM_ollie", "spin up", "Blue"],
    ["Total", "4.1_PDoS/monolayer_FM_ollie", "spin down", "green"]
    ], [-8, 4], [-8, 8], "Total")

# %%
# AFM

plot_dos_spin( "AFM DoS for o-B₁₄ monolayer", [["Total", "4.1_PDoS/monolayer_AFM_ollie", "spin up", "Purple"]], [-8, 4], [-8, 8], "Total")
