# %% [markdown]
# # Demonstration of Thesis

# %%
# Prework

from vmatplot.bandstructure import plot_bandstructure
from vmatplot.pdos import plot_single_pdos_pure
import matplotlib.pyplot as plt

# %%
# o-B₁₄ for Thesis

bs_list = ["monocolor", "", "3.1_bandstructure/o-B14_K48", "blue"]

plot_bandstructure("Bandstructure for o-B₁₄ bulk", bs_list, (-4,4), False)

plt.savefig("figures_collection/proj2.2a1.pdf")

# %%
# o-B₁₄ for Thesis

bs_list = ["monocolor", "", "3.1_bandstructure/o-B14_K48", "blue"]

plot_bandstructure("Bandstructure for o-B₁₄ bulk", bs_list, (-4,4), False)

# Change figure size after creation
fig = plt.gcf()
fig.set_size_inches(8, 6)

plt.savefig("figures_collection/proj2.2a1s.pdf")

# %%
# o-B14 Bulk

B2_index = (5,8)
B3_index = [1,2,3,4,13,14]
B7_index = (1,14)
current_dict = "4.1_PDoS/o-B14_K20"

systems = [
    # ["Total PDoS", current_dict, [], "total", "grey", "solid", 2.0, 1.0],
           ["$p$ for Group 1", current_dict, B2_index, "p", "blue", "solid", 2.0, 1.0],
           ["$s$ for Group 1", current_dict, B2_index, "s", "blue", "dashed", 2.0, 1.0],
           ["$p$ for Group 2", current_dict, B3_index, "p", "Orange", "solid", 2.0, 1.0],
           ["$s$ for Group 3", current_dict, B3_index, "s", "Orange", "dashed", 2.0, 1.0],
           ["$p$ for Group 3", current_dict, B7_index, "p", "Purple", "solid", 2.0, 1.0],
           ["$s$ for Group 3", current_dict, B7_index, "s", "Purple", "dashed", 2.0, 1.0]]

plot_single_pdos_pure("PDoS for o-B₁₄ Bulk", systems, 6, 6)

# Change figure size after creation
fig = plt.gcf()
fig.set_size_inches(8, 6)

plt.savefig("figures_collection/proj2.2bs.pdf")
