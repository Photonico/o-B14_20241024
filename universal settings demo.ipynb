# %%
# Check VASP work

from vmatplot.output_settings import vasprun_directory, plot_color_families, canvas_setting

Dir = "5.1_dielectric_function"

vasprun_directory(Dir)
# Out:
# All works are finished.
# ['5.1_dielectric_function/o-B14_n128_k10',
#  '5.1_dielectric_function/o-B14_n128_k12',
#  '5.1_dielectric_function/o-B14_n128_k14',
#  '5.1_dielectric_function/o-B14_n128_k16',
#  '5.1_dielectric_function/o-B14_n128_k18',
#  '5.1_dielectric_function/o-B14_n128_k20',
#  '5.1_dielectric_function/o-B14_n128_k22',
#  '5.1_dielectric_function/o-B14_n128_k24',
#  '5.1_dielectric_function/o-B14_n128_k26',
#  '5.1_dielectric_function/o-B14_n128_k28',
#  '5.1_dielectric_function/o-B14_n128_k30',
#  '5.1_dielectric_function/o-B14_n128_k32',
#  '5.1_dielectric_function/o-B14_n128_k34',
#  '5.1_dielectric_function/o-B14_n256_k10',
#  '5.1_dielectric_function/o-B14_n32_k10',
#  '5.1_dielectric_function/o-B14_n64_k10']

# %%
settings = canvas_setting()
settings
# Out:
# ((10, 6),
#  256,
#  {'text.usetex': False,
#   'font.family': 'serif',
#   'mathtext.fontset': 'cm',
#   'axes.titlesize': 20,
#   'axes.labelsize': 16,
#   'xtick.labelsize': 14,
#   'ytick.labelsize': 14,
#   'legend.fontsize': 12,
#   'figure.facecolor': 'w'},
#  (20, 18),
#  'upper right')

# %%
# Colors demo

plot_color_families()
